# %%
import pandas as pd

# %% [markdown]
# # --- file.csv --- prepare dataframe

# %%
df = pd.read_csv(r"data\d1.csv", encoding="utf-8", encoding_errors='ignore')
df=df.drop(columns="id")
print(df)
# Dataset is now stored in a Pandas Dataframe
